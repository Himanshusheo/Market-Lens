# %%
import pandas as pd
import numpy as np

# %%
df_investment=pd.read_csv("Media_Investment.csv")

# %%
df_master=pd.read_csv(r"C:\Users\shahj\Desktop\GC\Datasets\Master.csv")
# Out:
# C:\Users\shahj\AppData\Local\Temp\ipykernel_18508\1858165531.py:1: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_master=pd.read_csv(r"C:\Users\shahj\Desktop\GC\Datasets\Master.csv")

# %%
df_master['Date/Time']=pd.to_datetime(df_master['Date/Time'])
df_master['month_year'] = pd.to_datetime(df_master['order_date']).dt.to_period('M')
df_master['month']=pd.to_datetime(df_master['order_date']).dt.month
df_master['year']=pd.to_datetime(df_master['order_date']).dt.year

# %%
pivot_table = df_master.pivot_table(index='month_year', 
                                    columns='product_analytic_category', 
                                    values='gmv', 
                                    aggfunc='sum')
pivot_table = pivot_table.iloc[2:-1]

# %%
pivot_table
# Out:
# product_analytic_category        Camera  CameraAccessory  EntertainmentSmall  \
# month_year
# 2023-07                    4.606699e+07     1.741963e+07        8.380227e+07
# 2023-08                    6.155000e+04     4.227800e+04        2.581640e+05
# 2023-09                    1.369536e+08     4.591675e+07        1.773304e+08
# 2023-10                    2.417630e+08     3.194135e+07        1.804508e+08
# 2023-11                    1.630989e+08     2.363861e+07        9.370247e+07
# 2023-12                    2.070381e+08     2.861669e+07        1.247112e+08
# 2024-01                    1.869358e+08     2.638743e+07        1.092856e+08
# 2024-02                    1.549989e+08     2.536880e+07        1.004854e+08
# 2024-03                    1.861417e+08     2.676106e+07        1.202790e+08
# 2024-04                    1.470531e+08     2.534451e+07        9.804800e+07
# 2024-05                    1.844336e+08     3.052432e+07        1.104889e+08
# ...

# %%
df_investment['month_year'] = df_investment['Year'].astype(str) + '-' + df_investment['Month'].astype(str).str.zfill(2)

# %%
df_investment['month_year']=pd.to_datetime(df_investment['month_year']).dt.to_period('M')
df_investment.drop(['Month','Year'],axis=1,inplace=True)

# %%
df_investment.fillna(0)
# Out:
#     Total Investment   TV  Digital  Sponsorship  Content Marketing  \
# 0               17.1  0.2      2.5          7.4                0.0
# 1                5.1  0.0      1.3          1.1                0.0
# 2               96.3  3.9      1.4         62.8                0.6
# 3              170.2  6.1     12.6         84.7                3.4
# 4               51.2  4.2      1.3         14.2                0.2
# 5              106.7  5.4      3.1         56.7                1.1
# 6               74.2  4.4      0.5          4.2                0.9
# 7               48.1  2.6      1.9         11.7                0.6
# 8              100.0  9.3      2.1         41.6                0.4
# 9               56.8  5.2      0.9         24.3                0.0
# 10              78.1  1.4      0.8         31.7                0.8
# 11              42.8  1.7      1.4         25.0                0.0
# 12              42.8  1.7      1.4         25.0                0.0
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import plotly.express as px
import plotly.graph_objects as go

# 1. Clean and prepare data
df_investment_clean = df_investment.drop_duplicates(subset='month_year', keep='first')
df_investment_clean = df_investment_clean.set_index('month_year')
X = df_investment_clean.fillna(0)
# Drop 'Total Investment' column as it's redundant with individual channels
X = X.drop('Total Investment', axis=1)
X = X.apply(lambda x: x * 10**7 if x.name != 'month_year' else x)



# Make sure both X and y have the same index
common_index = X.index.intersection(pivot_table.index)
X = X.loc[common_index]
y = pivot_table.loc[common_index]

# 3. Ridge Regression Analysis
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
import lime
import lime.lime_tabular
import numpy as np
import json

# Create a LIME explainer
explainer = lime.lime_tabular.LimeTabularExplainer(
    training_data=X_scaled.values,  
    feature_names=X_scaled.columns.tolist(),  
    class_names=y.columns.tolist(),
    mode="regression"
)

# Pick a random instance to explain
i = np.random.randint(0, X_scaled.shape[0])  # Random sample index
lime_results = {"instance_index": int(i), "features": X_scaled.iloc[i].to_dict(), "explanations": {}}

for category in y.columns:
    # Explain a single prediction
    exp = explainer.explain_instance(
        X_scaled.iloc[i].values,  
        lambda x: rf.predict(x),  # Prediction function
        num_features=5  # Top 5 features affecting the prediction
    )

    # Store LIME feature importance in JSON format
    lime_results["explanations"][category] = {
        "top_features": [{feature: round(importance, 4)} for feature, importance in exp.as_list()]
    }

# Save results to JSON file
with open("lime_explanations.json", "w") as json_file:
    json.dump(lime_results, json_file, indent=4)

# Print JSON output
print(json.dumps(lime_results, indent=4))
# Out:
# c:\Users\shahj\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#
# c:\Users\shahj\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#
# c:\Users\shahj\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#
# c:\Users\shahj\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# {
#     "instance_index": 9,
#     "features": {
#         "TV": 0.5828448358416995,
# ...

# %%
import shap
import numpy as np

# Initialize SHAP explainer
shap_explainer = shap.TreeExplainer(rf)

# Compute SHAP values for all instances in X_scaled
shap_values = shap_explainer.shap_values(X_scaled)

# Store SHAP results for multiple instances
shap_results = []

# Iterate through multiple instances (first 5 as an example)
# Create a mapping of instance indices to meaningful names
instance_names = {
    0: "Camera",
    1: "CameraAccessory", 
    2: "EntertainmentSmall",
    3: "GameCDDVD",
    4: "GamingHardware"
}

for i in range(min(5, len(X_scaled))):  # Adjust number as needed
    instance_result = {
        "instance": instance_names[i],
        "features": X_scaled.iloc[i].to_dict(),
        "shap_explanations": {}
    }

    # Handle multi-output case (multiple target variables)
    if isinstance(shap_values, list):  
        for category_idx, category in enumerate(y.columns):
            instance_result["shap_explanations"][category] = {
                "feature_shap_values": {
                    feature: round(float(shap_values[category_idx][i, idx]), 4)  # Convert to float before rounding
                    for idx, feature in enumerate(X_scaled.columns)
                }
            }
    else:  
        # Handle single-output case
        instance_result["shap_explanations"]["single_output"] = {
            "feature_shap_values": {
                feature: round(float(shap_values[i, idx]), 4)  # Convert to float before rounding
                for idx, feature in enumerate(X_scaled.columns)
            }
        }

    shap_results.append(instance_result)

# Print SHAP values for multiple instances
for result in shap_results:
    print(result)
# Out:
# {'instance': 'Camera', 'features': {'TV': -1.3599712836306324, 'Digital': 0.005323141584835947, 'Sponsorship': -0.9177593478422158, 'Content Marketing': -0.7374603193648195, 'Online marketing': -1.8330157269986354, 'Affiliates': -1.8858379316683391, 'SEM': -0.3403491678186981, 'Radio': -0.4964450213929744, 'Other': -0.4838218045549669}, 'shap_explanations': {'single_output': {'feature_shap_values': {'TV': -6200448.8861, 'Digital': -1925562.5159, 'Sponsorship': -1080957.4937, 'Content Marketing': -1005974.019, 'Online marketing': -4145923.0225, 'Affiliates': -2710586.7399, 'SEM': 402758.5665, 'Radio': -403058.553, 'Other': -249593.6829}}}}
# ...
